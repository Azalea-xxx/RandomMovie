# %% [markdown]
# <a href="https://colab.research.google.com/github/Azalea-xxx/RandomMovie/blob/main/Project_Hemlet.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# базовая установка
# !pip install -U pip
# !pip install ultralytics kaggle opencv-python-headless matplotlib pycocotools
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 20.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: pip
#     Found existing installation: pip 24.1.2
#     Uninstalling pip-24.1.2:
#       Successfully uninstalled pip-24.1.2
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 22.9 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2/2 [ultralytics]
# ...

# %%
from google.colab import files
files.upload(C:\Users\ikama\Desktop\University\4 год\РО\kaggle.json)  # загрузи kaggle.json
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json
# скачиваем датасет
# !kaggle datasets download -d andrewmvd/hard-hat-detection -p /content
# !unzip -q /content/hard-hat-detection.zip -d /content/hardhat
# !ls -la /content/hardhat
